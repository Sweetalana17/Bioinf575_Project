# %% [markdown]
# Bioinformatics 575 Project - Option 1 Drug Annotation

# %% [markdown]
# Penelope Lialios:
# 1. The biggest challenge in this project for me was to handle the different ways in reporting the alleles for each source in Feature 2. PharmGKB reports single alleles, one genotype or two genotypes and 23andMe only reported single alleles. This was difficult for me to handle when indicating matches and mismatches.
# 2. I learned the importance of breaking down complex problems into parts to handle edge cases. When you first look at a problem all the different exceptions can seem daunting so breaking them up into small manageable steps makes it a lot easier.
# 3. I would want to answer: How many of the drugs are classified for each population to see if there are groups that are overrepresented or underrepresented in the annotation.

# %%
import pandas as pd

# %%
#Read in/Cleanup Files

#Load in 23 and me file and skip bad line
df23 = pd.read_csv(
    "23andme_v5_hg19_ref.txt.gz",
    sep="\t",
    comment="#",
    header = None,
    skiprows=[1458])

df23.columns = ["chrom", "pos", "rsid", "allele_23andme"]
df23
# Out:
#        chrom     pos         rsid allele_23andme
# 0       chr1   69869  rs548049170              T
# 1       chr1   74792   rs13328684              G
# 2       chr1  565508    rs9283150              G
# 3       chr1  726912      i713426              A
# 4       chr1  727841  rs116587930              G
# ...      ...     ...          ...            ...
# 638457  chrM   16524     i4000693              A
# 638458  chrM   16524      i704756              A
# 638459  chrM   16525      i705255              A
# 638460  chrM   16526     i4000757              G
# 638461  chrM   16526      i701671              G
#
# [638462 rows x 4 columns]

# %%
#Load in PharmGKB file 
pharmdf = pd.read_csv("var_drug_ann.tsv", sep="\t", dtype=str, on_bad_lines='skip')

# Keep only rows where Variant/Haplotypes starts with "rs"
pharm_rs = pharmdf[pharmdf["Variant/Haplotypes"].str.startswith("rs", na=False)].copy()

pharm_rs.head()
# Out:
#   Variant Annotation ID Variant/Haplotypes    Gene  \
# 1            1453073660          rs2909451    DPP4
# 2            1453071582           rs706795   FAIM2
# 3            1451138786         rs16918842   OPRK1
# 5            1453075980          rs2285676  KCNJ11
# 7            1453075960           rs163184   KCNQ1
#
#                                              Drug(s)      PMID  \
# 1                                        sitagliptin  39792745
# 2  citalopram, escitalopram, fluoxetine, fluvoxam...  40054571
# 3                                             heroin  31940240
# 5                                        sitagliptin  39792745
# 7                                        sitagliptin  39792745
#
#   Phenotype Category Significance  \
# 1           Efficacy          yes
# 2           Efficacy           no
# 3             Dosage           no
# 5           Efficacy          yes
# 7           Efficacy          yes
#
#                                                Notes  \
# 1  "Patients with the rs2909451 TT genotype in th...
# 2  "We observed nominally significant association...
# 3  No significant difference in allele or genotyp...
# 5  "For KCNJ11 gene polymorphisms, patients with ...
# 7  "KCNQ1 gene polymorphisms also significantly a...
#
#                                             Sentence Alleles  ... isPlural  \
# 1  Genotype TT is associated with decreased respo...      TT  ...       Is
# 2  Allele T is associated with increased response...       T  ...       Is
# 3  Allele T is not associated with dose of heroin...       T  ...       Is
# 5  Genotype GG is associated with increased respo...      GG  ...       Is
# 7  Genotype GG is associated with decreased respo...      GG  ...       Is
#
#   Is/Is Not associated Direction of effect  PD/PK terms Multiple drugs And/or  \
# 1      Associated with           decreased  response to                   NaN
# 2      Associated with           increased  response to                    or
# 3  Not associated with                 NaN      dose of                   NaN
# 5      Associated with           increased  response to                   NaN
# 7      Associated with           decreased  response to                   NaN
#
#   Population types    Population Phenotypes or diseases  \
# 1   in people with      Other:Diabetes Mellitus, Type 2
# 2   in people with  Other:Obsessive-Compulsive Disorder
# 3   in people with              Other:Heroin Dependence
# 5   in people with      Other:Diabetes Mellitus, Type 2
# 7   in people with      Other:Diabetes Mellitus, Type 2
#
#   Multiple phenotypes or diseases And/or Comparison Allele(s) or Genotype(s)  \
# 1                                    NaN                                 NaN
# 2                                    NaN                                   C
# 3                                    NaN                                   C
# 5                                    NaN                                 NaN
# 7                                    NaN                                 NaN
#
#   Comparison Metabolizer types
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 5                          NaN
# 7                          NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# 1. Map/merge the 23andme file and the variant-drug annotation file based on dbSNP_ID (also known as rsID).

# %%
#Merge 23andMe with PharmGKB on rsID 
merged = df23.merge(
    pharm_rs,
    left_on="rsid",
    right_on="Variant/Haplotypes",
    how="inner"
)

#Final columns for merged data
final_cols = {
    "rsid": "dbSNP_ID",
    "Gene": "GENE_SYMBOL",
    "Drug(s)": "DRUG_NAME",
    "PMID": "PMID",
    "Phenotype Category": "PHENOTYPE_CATEGORY",
    "Significance": "SIGNIFICANCE",
    "Notes": "NOTES",
    "Sentence": "SENTENCE",
    "Alleles": "ALLELE_PharmGKB",
    "allele_23andme": "ALLELE_23andme"
}

final_df = merged[list(final_cols.keys())].rename(columns=final_cols)

#Save the merged, annotated file for future use
final_df.to_csv("23andme_pharmgkb_merged.csv", index=False)

final_df
# Out:
#         dbSNP_ID GENE_SYMBOL  \
# 0      rs2651899      PRDM16
# 1     rs11807862      PRDM16
# 2       rs228729        PER3
# 3       rs228642        PER3
# 4       rs228666        PER3
# ...          ...         ...
# 6115   rs3810651       GABRQ
# 6116     rs17435       MECP2
# 6117   rs1734787       MECP2
# 6118   rs1734791       MECP2
# 6119   rs1050828        G6PD
#
#                                               DRUG_NAME      PMID  \
# 0                   Selective serotonin (5HT1) agonists  26502740
# 1     atorvastatin, HMG-CoA reductase inhibitors, si...  24096969
# 2                                               lithium  21781277
# 3                                               lithium  21781277
# 4                                               lithium  21781277
# ...                                                 ...       ...
# 6115                             botulinum toxin type a  31014225
# 6116              cisplatin, fluorouracil, mitoxantrone  21635146
# 6117              cisplatin, fluorouracil, mitoxantrone  21635146
# 6118              cisplatin, fluorouracil, mitoxantrone  21635146
# 6119                        artemisinin and derivatives  22940027
#
#      PHENOTYPE_CATEGORY SIGNIFICANCE  \
# 0              Efficacy          yes
# 1              Efficacy           no
# 2              Efficacy           no
# 3              Efficacy           no
# 4              Efficacy           no
# ...                 ...          ...
# 6115           Efficacy           no
# 6116           Efficacy          yes
# 6117           Efficacy          yes
# 6118           Efficacy          yes
# 6119           Efficacy           no
#
#                                                   NOTES  \
# 0     "Hence, the following risk alleles were determ...
# 1     There could be strand confusion with this A/T ...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6115  No significant difference in allele frequency ...
# 6116  The study described this variant within the ME...
# 6117  The study described this variant within the ME...
# 6118  The study described this variant within the ME...
# 6119  G6PD deficient (those with genotype TT, TC, or...
#
#                                                SENTENCE ALLELE_PharmGKB  \
# 0     Allele C is associated with increased response...               C
# 1     Genotype AA is associated with decreased respo...              AA
# 2     Allele T is not associated with increased resp...               T
# 3     Allele C is not associated with increased resp...               C
# 4     Allele C is not associated with increased resp...               C
# ...                                                 ...             ...
# 6115  Allele T is not associated with response to bo...               T
# 6116  Allele A is associated with response to cispla...               A
# 6117  Allele A is associated with response to cispla...               A
# 6118  Allele A is associated with response to cispla...               A
# 6119  Allele T is not associated with response to ar...               T
#
#      ALLELE_23andme
# 0                 T
# 1                 T
# 2                 T
# 3                 C
# 4                 T
# ...             ...
# 6115              T
# 6116              T
# 6117              A
# 6118              A
# 6119              C
#
# [6120 rows x 10 columns]

# %% [markdown]
# 2. Filter the output so that it only contains significant associations (SIGNIFICANCE is yes) for variants that affect the drug efficacy (`PHENOTYPE_CATEGORY` is `efficacy`).

# %%
#Filtering rows to keep only samples with 'Significanace' == 'yes' and 'phenotype_category' == 'Efficacy'
filtered_df = final_df[(final_df['PHENOTYPE_CATEGORY'] == 'Efficacy') & (final_df['SIGNIFICANCE'] == 'yes')] #Selection code
filtered_df
# Out:
#        dbSNP_ID GENE_SYMBOL  \
# 0     rs2651899      PRDM16
# 9     rs1801131       MTHFR
# 11    rs1801131       MTHFR
# 14    rs1801131       MTHFR
# 17    rs1801131       MTHFR
# ...         ...         ...
# 6111   rs502434       GRIA3
# 6114  rs3810651       GABRQ
# 6116    rs17435       MECP2
# 6117  rs1734787       MECP2
# 6118  rs1734791       MECP2
#
#                                               DRUG_NAME      PMID  \
# 0                   Selective serotonin (5HT1) agonists  26502740
# 9                                           oxaliplatin  20385995
# 11                Vitamin B-complex, Incl. Combinations  27035272
# 14                fluorouracil, leucovorin, oxaliplatin  20078613
# 17                                         methotrexate  24386571
# ...                                                 ...       ...
# 6111  Selective serotonin reuptake inhibitors, venla...  23394390
# 6114                                        venlafaxine  23394390
# 6116              cisplatin, fluorouracil, mitoxantrone  21635146
# 6117              cisplatin, fluorouracil, mitoxantrone  21635146
# 6118              cisplatin, fluorouracil, mitoxantrone  21635146
#
#      PHENOTYPE_CATEGORY SIGNIFICANCE  \
# 0              Efficacy          yes
# 9              Efficacy          yes
# 11             Efficacy          yes
# 14             Efficacy          yes
# 17             Efficacy          yes
# ...                 ...          ...
# 6111           Efficacy          yes
# 6114           Efficacy          yes
# 6116           Efficacy          yes
# 6117           Efficacy          yes
# 6118           Efficacy          yes
#
#                                                   NOTES  \
# 0     "Hence, the following risk alleles were determ...
# 9     Statistics given as trend for increased overal...
# 11    Please note that allele has been complemented ...
# 14                                                  NaN
# 17    Patients with the TT genotype had significantl...
# ...                                                 ...
# 6111  Regression model looking at interaction betwee...
# 6114  Those with the AA/AT genotype are more likely ...
# 6116  The study described this variant within the ME...
# 6117  The study described this variant within the ME...
# 6118  The study described this variant within the ME...
#
#                                                SENTENCE ALLELE_PharmGKB  \
# 0     Allele C is associated with increased response...               C
# 9     Genotypes GG + GT are associated with increase...         GG + GT
# 11    Allele G is associated with increased response...               G
# 14    Allele G is associated with increased response...               G
# 17    Genotype TT is associated with decreased respo...              TT
# ...                                                 ...             ...
# 6111  Genotype CC is associated with decreased respo...              CC
# 6114  Genotypes AA + AT are associated with increase...         AA + AT
# 6116  Allele A is associated with response to cispla...               A
# 6117  Allele A is associated with response to cispla...               A
# 6118  Allele A is associated with response to cispla...               A
#
#      ALLELE_23andme
# 0                 T
# 9                 T
# 11                T
# 14                T
# 17                T
# ...             ...
# 6111              T
# 6114              T
# 6116              T
# 6117              A
# 6118              A
#
# [1435 rows x 10 columns]

# %% [markdown]
# 3. Save the output of the filtering step in a tab-separated file (23andme_PharmGKB_map.tsv) with the following columns:
# dbSNP_ID, GENE_SYMBOL, DRUG_NAME, NOTES, SENTENCE, ALLELE_PharmGKB, ALLELE_23andme

# %%
#Required final columns
final_cols_list = [
    'dbSNP_ID', 
    'GENE_SYMBOL', 
    'DRUG_NAME', 
    'NOTES', 
    'SENTENCE', 
    'ALLELE_PharmGKB', 
    'ALLELE_23andme'
]

#Selecting only those columns from the filtered data
final_output_df = filtered_df[final_cols_list]
final_output_df
# Out:
#        dbSNP_ID GENE_SYMBOL  \
# 0     rs2651899      PRDM16
# 9     rs1801131       MTHFR
# 11    rs1801131       MTHFR
# 14    rs1801131       MTHFR
# 17    rs1801131       MTHFR
# ...         ...         ...
# 6111   rs502434       GRIA3
# 6114  rs3810651       GABRQ
# 6116    rs17435       MECP2
# 6117  rs1734787       MECP2
# 6118  rs1734791       MECP2
#
#                                               DRUG_NAME  \
# 0                   Selective serotonin (5HT1) agonists
# 9                                           oxaliplatin
# 11                Vitamin B-complex, Incl. Combinations
# 14                fluorouracil, leucovorin, oxaliplatin
# 17                                         methotrexate
# ...                                                 ...
# 6111  Selective serotonin reuptake inhibitors, venla...
# 6114                                        venlafaxine
# 6116              cisplatin, fluorouracil, mitoxantrone
# 6117              cisplatin, fluorouracil, mitoxantrone
# 6118              cisplatin, fluorouracil, mitoxantrone
#
#                                                   NOTES  \
# 0     "Hence, the following risk alleles were determ...
# 9     Statistics given as trend for increased overal...
# 11    Please note that allele has been complemented ...
# 14                                                  NaN
# 17    Patients with the TT genotype had significantl...
# ...                                                 ...
# 6111  Regression model looking at interaction betwee...
# 6114  Those with the AA/AT genotype are more likely ...
# 6116  The study described this variant within the ME...
# 6117  The study described this variant within the ME...
# 6118  The study described this variant within the ME...
#
#                                                SENTENCE ALLELE_PharmGKB  \
# 0     Allele C is associated with increased response...               C
# 9     Genotypes GG + GT are associated with increase...         GG + GT
# 11    Allele G is associated with increased response...               G
# 14    Allele G is associated with increased response...               G
# 17    Genotype TT is associated with decreased respo...              TT
# ...                                                 ...             ...
# 6111  Genotype CC is associated with decreased respo...              CC
# 6114  Genotypes AA + AT are associated with increase...         AA + AT
# 6116  Allele A is associated with response to cispla...               A
# 6117  Allele A is associated with response to cispla...               A
# 6118  Allele A is associated with response to cispla...               A
#
#      ALLELE_23andme
# 0                 T
# 9                 T
# 11                T
# 14                T
# 17                T
# ...             ...
# 6111              T
# 6114              T
# 6116              T
# 6117              A
# 6118              A
#
# [1435 rows x 7 columns]

# %%
#Saving the filtered data into a tsv file
final_output_df.to_csv("23andme_PharmGKB_map.tsv", index=False, sep='\t')
final_output_df
# Out:
#        dbSNP_ID GENE_SYMBOL  \
# 0     rs2651899      PRDM16
# 9     rs1801131       MTHFR
# 11    rs1801131       MTHFR
# 14    rs1801131       MTHFR
# 17    rs1801131       MTHFR
# ...         ...         ...
# 6111   rs502434       GRIA3
# 6114  rs3810651       GABRQ
# 6116    rs17435       MECP2
# 6117  rs1734787       MECP2
# 6118  rs1734791       MECP2
#
#                                               DRUG_NAME  \
# 0                   Selective serotonin (5HT1) agonists
# 9                                           oxaliplatin
# 11                Vitamin B-complex, Incl. Combinations
# 14                fluorouracil, leucovorin, oxaliplatin
# 17                                         methotrexate
# ...                                                 ...
# 6111  Selective serotonin reuptake inhibitors, venla...
# 6114                                        venlafaxine
# 6116              cisplatin, fluorouracil, mitoxantrone
# 6117              cisplatin, fluorouracil, mitoxantrone
# 6118              cisplatin, fluorouracil, mitoxantrone
#
#                                                   NOTES  \
# 0     "Hence, the following risk alleles were determ...
# 9     Statistics given as trend for increased overal...
# 11    Please note that allele has been complemented ...
# 14                                                  NaN
# 17    Patients with the TT genotype had significantl...
# ...                                                 ...
# 6111  Regression model looking at interaction betwee...
# 6114  Those with the AA/AT genotype are more likely ...
# 6116  The study described this variant within the ME...
# 6117  The study described this variant within the ME...
# 6118  The study described this variant within the ME...
#
#                                                SENTENCE ALLELE_PharmGKB  \
# 0     Allele C is associated with increased response...               C
# 9     Genotypes GG + GT are associated with increase...         GG + GT
# 11    Allele G is associated with increased response...               G
# 14    Allele G is associated with increased response...               G
# 17    Genotype TT is associated with decreased respo...              TT
# ...                                                 ...             ...
# 6111  Genotype CC is associated with decreased respo...              CC
# 6114  Genotypes AA + AT are associated with increase...         AA + AT
# 6116  Allele A is associated with response to cispla...               A
# 6117  Allele A is associated with response to cispla...               A
# 6118  Allele A is associated with response to cispla...               A
#
#      ALLELE_23andme
# 0                 T
# 9                 T
# 11                T
# 14                T
# 17                T
# ...             ...
# 6111              T
# 6114              T
# 6116              T
# 6117              A
# 6118              A
#
# [1435 rows x 7 columns]

# %% [markdown]
# 4. Create a tab separated file (23andme_PharmGKB_summary.tsv) with summarized data with the following columns:
#
# GENE_SYMBOL, DRUG_NAME, dbSNP_IDs (list of IDs separated by ";")

# %%
summary_df = (final_output_df[['GENE_SYMBOL', 'DRUG_NAME', 'dbSNP_ID']]
              .drop_duplicates()
              .groupby(['GENE_SYMBOL', 'DRUG_NAME'])
              .agg(dbSNP_IDs=('dbSNP_ID', ';'.join))
              .reset_index())

#Check the first few rows  
summary_df.head()

# Save in the required tab seperated file
summary_df.to_csv("23andme_PharmGKB_summary.tsv", index=False, sep='\t')

# %% [markdown]
# 5. Plot the distribution (histogram) of the number of drugs associated with a gene, and the number of SNPs for a gene.

# %%
import matplotlib.pyplot as plt

# %%
#For each gene, how many drugs it's associated with
#For each gene, how many SNPs

NumberOfDrugsInGene = summary_df.groupby("GENE_SYMBOL")["DRUG_NAME"].nunique()

plt.hist(NumberOfDrugsInGene, bins=20, edgecolor="black")
plt.xlabel("Number of Drugs Associated with a Gene")     
plt.ylabel("Count of Genes")                             
plt.title("Distribution of Number of Drugs Associated with a Gene")
plt.show()

# %%
NumberOfSNPsInGene = filtered_df.groupby("GENE_SYMBOL")["dbSNP_ID"].nunique()
plt.hist(NumberOfSNPsInGene, bins=20, edgecolor="black", color='orange')
plt.xlabel("Number of SNPs Associated with a Gene")     
plt.ylabel("Count of Genes")                             
plt.title("Distribution of Number of SNPs Associated with a Gene")
plt.show()

# %% [markdown]
# 6. New feature
#
# How many of the dbsnp ids from 23andMe report are not present in Variant/Haplotypes annotation file

# %%
rs_23andme = set(df23["rsid"].dropna())
#print(rs_23andme)
rs_pharmgkb = set(pharm_rs["Variant/Haplotypes"].dropna())
#print(rs_pharmgkb)

# %%
#rsIDs present in only 23andme report 
ids_only_23andme = rs_23andme - rs_pharmgkb

print("IDs present only in 23andMe:", len(ids_only_23andme))


df_only_23andme = df23[df23["rsid"].isin(ids_only_23andme)][["rsid", "chrom", "pos", "allele_23andme"]]
df_only_23andme

df_only_23andme.to_csv("23andme_unannotated_snps.tsv", index=False, sep='\t')


##These are variants in this individual’s genome that have not yet been studied for drug response according to PharmGKB
#Biologically this is relevant because it shows the gap in pharmacogenomic knowledge for this individual i.e 
#these unannotated SNPs represent variants in genes affecting drug response that either have not yet been studied or
#haven't been reported, thus providing insights into areas for further research
# Out:
# IDs present only in 23andMe: 636589

# %% [markdown]
# New Feature 2 - Penelope Lialios

# %% [markdown]
# Identifying mismatches between the 23andMe sample and the PharmGKB risk alleles. By determining if the sample genotype matches the PharmGKB risk alleles, we can determine if that specific drug would be effective on that person.
#
# AI use: helped deal with the PharmGKB multiple genotypes cases (how some cases have CC+CT)

# %%
#Only looking at significant associations 
#Adds a column with match status 

#Fixes index errror
final_output_df_feature2 = final_output_df.copy().reset_index(drop=True)

final_output_df_feature2["match_status"] = ""

for i in range(len(final_output_df_feature2)):
    
    pharm_allele = str(final_output_df_feature2.loc[i, "ALLELE_PharmGKB"]).upper().strip()
    sample_allele = str(final_output_df_feature2.loc[i, "ALLELE_23andme"]).upper().strip()


    #Handle haploid vs diploid sample
    if len(sample_allele) == 1:
        sample_haploid = True
        sample_sorted = sample_allele
    else:
        sample_haploid = False
        sample_sorted = "".join(sorted(sample_allele))

    #Split PharmGKB by +
    genotype_options = [g.strip() for g in pharm_allele.split("+") if g.strip() != ""]

    match_found = False

    for g in genotype_options:
        g = g.strip()

        #Homozygous (CC) or heterozygous (CT)
        if len(g) == 2:  
            if sample_haploid:
              #Haploid sample: match if alleles in PharmGKB genotype is in sample
                if any(allele in sample_sorted for allele in g):
                    match_found = True
                    break
            else:
                #Diploid sample: match if any alleles in PharmGKB genotype are in sample
                if all(allele in sample_sorted for allele in g):
                    match_found = True
                    break
        elif len(g) == 1:  #Single allele 
            if g in sample_sorted:
                match_found = True
                break

    final_output_df_feature2.loc[i, "match_status"] = "match" if match_found else "mismatch"

final_output_df_feature2
# Out:
#        dbSNP_ID GENE_SYMBOL  \
# 0     rs2651899      PRDM16
# 1     rs1801131       MTHFR
# 2     rs1801131       MTHFR
# 3     rs1801131       MTHFR
# 4     rs1801131       MTHFR
# ...         ...         ...
# 1430   rs502434       GRIA3
# 1431  rs3810651       GABRQ
# 1432    rs17435       MECP2
# 1433  rs1734787       MECP2
# 1434  rs1734791       MECP2
#
#                                               DRUG_NAME  \
# 0                   Selective serotonin (5HT1) agonists
# 1                                           oxaliplatin
# 2                 Vitamin B-complex, Incl. Combinations
# 3                 fluorouracil, leucovorin, oxaliplatin
# 4                                          methotrexate
# ...                                                 ...
# 1430  Selective serotonin reuptake inhibitors, venla...
# 1431                                        venlafaxine
# 1432              cisplatin, fluorouracil, mitoxantrone
# 1433              cisplatin, fluorouracil, mitoxantrone
# 1434              cisplatin, fluorouracil, mitoxantrone
#
#                                                   NOTES  \
# 0     "Hence, the following risk alleles were determ...
# 1     Statistics given as trend for increased overal...
# 2     Please note that allele has been complemented ...
# 3                                                   NaN
# 4     Patients with the TT genotype had significantl...
# ...                                                 ...
# 1430  Regression model looking at interaction betwee...
# 1431  Those with the AA/AT genotype are more likely ...
# 1432  The study described this variant within the ME...
# 1433  The study described this variant within the ME...
# 1434  The study described this variant within the ME...
#
#                                                SENTENCE ALLELE_PharmGKB  \
# 0     Allele C is associated with increased response...               C
# 1     Genotypes GG + GT are associated with increase...         GG + GT
# 2     Allele G is associated with increased response...               G
# 3     Allele G is associated with increased response...               G
# 4     Genotype TT is associated with decreased respo...              TT
# ...                                                 ...             ...
# 1430  Genotype CC is associated with decreased respo...              CC
# 1431  Genotypes AA + AT are associated with increase...         AA + AT
# 1432  Allele A is associated with response to cispla...               A
# 1433  Allele A is associated with response to cispla...               A
# 1434  Allele A is associated with response to cispla...               A
#
#      ALLELE_23andme match_status
# 0                 T     mismatch
# 1                 T        match
# 2                 T     mismatch
# 3                 T     mismatch
# 4                 T        match
# ...             ...          ...
# 1430              T     mismatch
# 1431              T        match
# 1432              T     mismatch
# 1433              A        match
# 1434              A        match
#
# [1435 rows x 8 columns]

# %% [markdown]
# This feature allows us to directly compare the sample's variants from 23andMe to known drug response variants. This can help with predicting accuracy of drugs for certain people. This feature handles the single alleles reported in 23andMe and can compare it to single alleles and multi-genotype scenarios which is important when using two different sources to handle all the different cases. This data can be used to quantify the prevalence of actionable variants across the dataset which provides insight into population-level patterns.
